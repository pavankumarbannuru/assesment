# %%
import pandas as pd 
import numpy as np

# %%
df2=pd.read_csv(r"C:\Users\pbann\Downloads\session-datasets-20230425T044943Z-001\session-datasets\datasets-session-17\movies.csv")
df1=pd.read_csv(r"C:\Users\pbann\Downloads\session-datasets-20230425T044943Z-001\session-datasets\datasets-session-17\diabetes.csv")
df=pd.read_csv(r"C:\Users\pbann\Downloads\session-datasets-20230425T044943Z-001\session-datasets\datasets-session-17\ipl-matches.csv")

# %%
df.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field
# ...

# %%
df2.head()
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 1        https://en.wikipedia.org/wiki/Battalion_609
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 3      https://en.wikipedia.org/wiki/Why_Cheat_India
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
#
# ...

# %%
df3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_24052\3646215654.py in <module>
# ----> 1 df3.head()
#
# NameError: name 'df3' is not defined

# %%
df.shape
# Out:
# (950, 20)

# %%
df.size
# Out:
# 19000

# %%
df.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
df.columns
# Out:
# Index(['ID', 'City', 'Date', 'Season', 'MatchNumber', 'Team1', 'Team2',
#        'Venue', 'TossWinner', 'TossDecision', 'SuperOver', 'WinningTeam',
#        'WonBy', 'Margin', 'method', 'Player_of_Match', 'Team1Players',
#        'Team2Players', 'Umpire1', 'Umpire2'],
#       dtype='object')

# %%
df.values
# Out:
# array([[1312200, 'Ahmedabad', '2022-05-29', ...,
#         "['WP Saha', 'Shubman Gill', 'MS Wade', 'HH Pandya', 'DA Miller', 'R Tewatia', 'Rashid Khan', 'R Sai Kishore', 'LH Ferguson', 'Yash Dayal', 'Mohammed Shami']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312199, 'Ahmedabad', '2022-05-27', ...,
#         "['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D Padikkal', 'SO Hetmyer', 'R Parag', 'R Ashwin', 'TA Boult', 'YS Chahal', 'M Prasidh Krishna', 'OC McCoy']",
#         'CB Gaffaney', 'Nitin Menon'],
#        [1312198, 'Kolkata', '2022-05-25', ...,
#         "['Q de Kock', 'KL Rahul', 'M Vohra', 'DJ Hooda', 'MP Stoinis', 'E Lewis', 'KH Pandya', 'PVD Chameera', 'Mohsin Khan', 'Avesh Khan', 'Ravi Bishnoi']",
#         'J Madanagopal', 'MA Gough'],
#        ...,
#        [335984, 'Delhi', '2008-04-19', ...,
#         "['T Kohli', 'YK Pathan', 'SR Watson', 'M Kaif', 'DS Lehmann', 'RA Jadeja', 'M Rawat', 'D Salunkhe', 'SK Warne', 'SK Trivedi', 'MM Patel']",
# ...

# %%
df.sample(3)
# Out:
#          ID        City        Date   Season MatchNumber                Team1  \
# 513  734007   Hyderabad  2014-05-14     2014          39  Sunrisers Hyderabad
# 940  335991  Chandigarh  2008-04-25  2007/08          10      Kings XI Punjab
# 788  419152      Mumbai  2010-04-13  2009/10          47       Mumbai Indians
#
#                 Team2                                       Venue  \
# 513   Kings XI Punjab   Rajiv Gandhi International Stadium, Uppal
# 940    Mumbai Indians  Punjab Cricket Association Stadium, Mohali
# 788  Delhi Daredevils                           Brabourne Stadium
#
#           TossWinner TossDecision SuperOver      WinningTeam    WonBy  Margin  \
# 513  Kings XI Punjab        field         N  Kings XI Punjab  Wickets     6.0
# 940   Mumbai Indians        field         N  Kings XI Punjab     Runs    66.0
# 788   Mumbai Indians          bat         N   Mumbai Indians     Runs    39.0
#
# ...

# %%
df.isnull().sum()
# Out:
# ID                   0
# City                51
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.describe()
# Out:
#                  ID      Margin
# count  9.500000e+02  932.000000
# mean   8.304852e+05   17.056867
# std    3.375678e+05   21.633109
# min    3.359820e+05    1.000000
# 25%    5.012612e+05    6.000000
# 50%    8.297380e+05    8.000000
# 75%    1.175372e+06   19.000000
# max    1.312200e+06  146.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.rename(columns={'ID':'Match_ID'},inplace=True)

# %%
df1.sum()
# Out:
# Pregnancies                  2953.000
# Glucose                     92847.000
# BloodPressure               53073.000
# SkinThickness               15772.000
# Insulin                     61286.000
# BMI                         24570.300
# DiabetesPedigreeFunction      362.401
# Age                         25529.000
# Outcome                       268.000
# dtype: float64

# %%
df1.mean()
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df1.std()
# Out:
# Pregnancies                   3.369578
# Glucose                      31.972618
# BloodPressure                19.355807
# SkinThickness                15.952218
# Insulin                     115.244002
# BMI                           7.884160
# DiabetesPedigreeFunction      0.331329
# Age                          11.760232
# Outcome                       0.476951
# dtype: float64

# %%
df1['Pregnancies']
# Out:
# 0       6
# 1       1
# 2       8
# 3       1
# 4       0
#        ..
# 763    10
# 764     2
# 765     5
# 766     1
# 767     1
# Name: Pregnancies, Length: 768, dtype: int64

# %%
df1[['Pregnancies','Glucose','BloodPressure']]
# Out:
#      Pregnancies  Glucose  BloodPressure
# 0              6      148             72
# 1              1       85             66
# 2              8      183             64
# 3              1       89             66
# 4              0      137             40
# ..           ...      ...            ...
# 763           10      101             76
# 764            2      122             70
# 765            5      121             72
# 766            1      126             60
# 767            1       93             70
#
# [768 rows x 3 columns]

# %%
df1.set_index('Pregnancies',inplace=True)
df1
# Out:
#              Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# Pregnancies
# 6                148             72             35        0  33.6
# 1                 85             66             29        0  26.6
# 8                183             64              0        0  23.3
# 1                 89             66             23       94  28.1
# 0                137             40             35      168  43.1
# ...              ...            ...            ...      ...   ...
# 10               101             76             48      180  32.9
# 2                122             70             27        0  36.8
# 5                121             72             23      112  26.2
# 1                126             60              0        0  30.1
# 1                 93             70             31        0  30.4
#
#              DiabetesPedigreeFunction  Age  Outcome
# Pregnancies
# 6                               0.627   50        1
# ...

# %%
df1.reset_index(inplace=True)
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1.iloc[5:10]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 5                     0.201   30        0
# 6                     0.248   26        1
# 7                     0.134   29        0
# 8                     0.158   53        1
# 9                     0.232   54        1

# %%
df1.iloc[[0,4,3]]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 4            0      137             40             35      168  43.1
# 3            1       89             66             23       94  28.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 4                     2.288   33        1
# 3                     0.167   21        0

# %%
df
# Out:
#            City       ID        Date   Season  MatchNumber  \
# 0     Ahmedabad  1312200  2022-05-29     2022        Final
# 1     Ahmedabad  1312199  2022-05-27     2022  Qualifier 2
# 2       Kolkata  1312198  2022-05-25     2022   Eliminator
# 3       Kolkata  1312197  2022-05-24     2022  Qualifier 1
# 4        Mumbai  1304116  2022-05-22     2022           70
# ..          ...      ...         ...      ...          ...
# 945     Kolkata   335986  2008-04-20  2007/08            4
# 946      Mumbai   335985  2008-04-20  2007/08            5
# 947       Delhi   335984  2008-04-19  2007/08            3
# 948  Chandigarh   335983  2008-04-19  2007/08            2
# 949   Bangalore   335982  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
df.set_index('City',inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df.loc[['Ahmedabad','Bangalore']]
# Out:
#                 ID        Date   Season  MatchNumber  \
# City
# Ahmedabad  1312200  2022-05-29     2022        Final
# Ahmedabad  1312199  2022-05-27     2022  Qualifier 2
# Ahmedabad  1254086  2021-05-02     2021           29
# Ahmedabad  1254083  2021-04-30     2021           26
# Ahmedabad  1254082  2021-04-29     2021           25
# ...            ...         ...      ...          ...
# Bangalore   336006  2008-05-05  2007/08           25
# Bangalore   336034  2008-05-03  2007/08           21
# Bangalore   335996  2008-04-28  2007/08           15
# Bangalore   335992  2008-04-26  2007/08           12
# Bangalore   335982  2008-04-18  2007/08            1
#
#                                  Team1                        Team2  \
# City
# Ahmedabad             Rajasthan Royals               Gujarat Titans
# Ahmedabad  Royal Challengers Bangalore             Rajasthan Royals
# Ahmedabad                 Punjab Kings               Delhi Capitals
# ...

# %%
df[(df['City']=='Ahmedabad')| (df['City']=='Bangalore')]
# Out:
#           City       ID        Date   Season  MatchNumber  \
# 0    Ahmedabad  1312200  2022-05-29     2022        Final
# 1    Ahmedabad  1312199  2022-05-27     2022  Qualifier 2
# 105  Ahmedabad  1254086  2021-05-02     2021           29
# 108  Ahmedabad  1254083  2021-04-30     2021           26
# 109  Ahmedabad  1254082  2021-04-29     2021           25
# ..         ...      ...         ...      ...          ...
# 925  Bangalore   336006  2008-05-05  2007/08           25
# 928  Bangalore   336034  2008-05-03  2007/08           21
# 935  Bangalore   335996  2008-04-28  2007/08           15
# 939  Bangalore   335992  2008-04-26  2007/08           12
# 949  Bangalore   335982  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 105                 Punjab Kings               Delhi Capitals
# ...

# %%
df[df['Venue'].str.split().apply(lambda x : 'Ahmedabad' in x)]
# Out:
#           City       ID        Date Season  MatchNumber  \
# 0    Ahmedabad  1312200  2022-05-29   2022        Final
# 1    Ahmedabad  1312199  2022-05-27   2022  Qualifier 2
# 105  Ahmedabad  1254086  2021-05-02   2021           29
# 108  Ahmedabad  1254083  2021-04-30   2021           26
# 109  Ahmedabad  1254082  2021-04-29   2021           25
# 112  Ahmedabad  1254079  2021-04-27   2021           22
# 113  Ahmedabad  1254078  2021-04-26   2021           21
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 105                 Punjab Kings               Delhi Capitals
# 108                 Punjab Kings  Royal Challengers Bangalore
# 109        Kolkata Knight Riders               Delhi Capitals
# 112  Royal Challengers Bangalore               Delhi Capitals
# 113                 Punjab Kings        Kolkata Knight Riders
#
# ...

# %%
df.isnull().sum()
# Out:
# City                51
# ID                   0
# Date                 0
# Season               0
# MatchNumber          0
# Team1                0
# Team2                0
# Venue                0
# TossWinner           0
# TossDecision         0
# SuperOver            4
# WinningTeam          4
# WonBy                0
# Margin              18
# method             931
# Player_of_Match      4
# Team1Players         0
# Team2Players         0
# Umpire1              0
# Umpire2              0
# dtype: int64

# %%
df.dropna(subset=['Margin','MatchNumber','City'],inplace=True)  # remove those where margin column has nan values

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# ID                 0
# City               0
# Date               0
# Season             0
# MatchNumber        0
# Team1              0
# Team2              0
# Venue              0
# TossWinner         0
# TossDecision       0
# SuperOver          0
# WinningTeam        0
# WonBy              0
# Margin             0
# method             0
# Player_of_Match    0
# Team1Players       0
# Team2Players       0
# Umpire1            0
# Umpire2            0
# dtype: int64

# %%
df['City'].fillna(df['City'].mode(),inplace=True)

# %%
df[df['City']=='nan']
# Out:
# Empty DataFrame
# Columns: [ID, City, Date, Season, MatchNumber, Team1, Team2, Venue, TossWinner, TossDecision, SuperOver, WinningTeam, WonBy, Margin, method, Player_of_Match, Team1Players, Team2Players, Umpire1, Umpire2]
# Index: []

# %%
df['City'].unique()
# Out:
# array(['Ahmedabad', 'Kolkata', 'Mumbai', 'Navi Mumbai', 'Pune', 'Dubai',
#        'Sharjah', 'Abu Dhabi', 'Delhi', 'Chennai', nan, 'Hyderabad',
#        'Visakhapatnam', 'Chandigarh', 'Bengaluru', 'Jaipur', 'Indore',
#        'Bangalore', 'Kanpur', 'Rajkot', 'Raipur', 'Ranchi', 'Cuttack',
#        'Dharamsala', 'Kochi', 'Nagpur', 'Johannesburg', 'Centurion',
#        'Durban', 'Bloemfontein', 'Port Elizabeth', 'Kimberley',
#        'East London', 'Cape Town'], dtype=object)

# %%
df['City'].dropna(inplace=True)

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#           ID           City        Date   Season MatchNumber  \
# 282  1136592          Delhi  2018-05-02     2018          32
# 296  1136578        Kolkata  2018-04-21     2018          18
# 308  1136566         Jaipur  2018-04-11     2018           6
# 316  1082648      Bangalore  2017-05-17     2017  Eliminator
# 383   980999      Bangalore  2016-05-18     2016          50
# 384   980997  Visakhapatnam  2016-05-17     2016          49
# 389   980989        Kolkata  2016-05-14     2016          45
# 411   980943      Hyderabad  2016-04-26     2016          22
# 441   829807      Hyderabad  2015-05-15     2015          52
# 472   829743  Visakhapatnam  2015-04-22     2015          19
# 520   733993          Delhi  2014-05-10     2014          32
# 717   501255      Bangalore  2011-05-14     2011          58
# 728   501245        Kolkata  2011-05-07     2011          48
# 757   501215          Kochi  2011-04-18     2011          18
# ...

# %%
df.groupby('City').sum()
# Out:
#                     ID  Margin
# City
# Bangalore      2564902    93.0
# Cape Town       392183    10.0
# Centurion       392214    12.0
# Delhi          2206607    18.0
# Durban          392186    11.0
# Hyderabad      1810750    40.0
# Jaipur         1136566    10.0
# Kochi           501215     7.0
# Kolkata        2954837    30.0
# Visakhapatnam  1810740    35.0

# %%
df2.columns
# Out:
# Index(['title_x', 'imdb_id', 'poster_path', 'wiki_link', 'title_y',
#        'original_title', 'is_adult', 'year_of_release', 'runtime', 'genres',
#        'imdb_rating', 'imdb_votes', 'story', 'summary', 'tagline', 'actors',
#        'wins_nominations', 'release_date'],
#       dtype='object')

# %%
df2.groupby('year_of_release').mean()
# Out:
#                  is_adult  imdb_rating   imdb_votes
# year_of_release
# 2001                  0.0     5.636066  6356.180328
# 2002                  0.0     5.142105  2027.828947
# 2003                  0.0     5.518182  3050.989899
# 2004                  0.0     5.251899  4144.569620
# 2005                  0.0     5.356701  2408.762887
# 2006                  0.0     5.375294  5295.458824
# 2007                  0.0     5.600000  6561.190476
# 2008                  0.0     5.208219  4322.726027
# 2009                  0.0     5.598413  8547.857143
# 2010                  0.0     5.492391  4352.250000
# 2011                  0.0     5.475000  5167.130952
# 2012                  0.0     5.632530  8749.975904
# 2013                  0.0     5.734043  7624.563830
# 2014                  0.0     5.429091  5578.254545
# 2015                  0.0     5.653333  6414.857143
# 2016                  0.0     5.644681  6941.595745
# 2017                  0.0     5.838542  3939.354167
# ...

# %%
df2.groupby('genres')['imdb_rating'].sum().sort_values()
# Out:
# genres
# Drama|Short                0.0
# Biography|History          0.0
# Comedy|Family|Sci-Fi       2.4
# Action|Crime|Romance       2.4
# Action|Fantasy|Sci-Fi      2.6
#                          ...
# Drama|Romance            463.5
# Comedy|Drama             497.5
# Action|Crime|Drama       501.9
# Comedy|Drama|Romance     573.9
# Drama                    987.4
# Name: imdb_rating, Length: 205, dtype: float64

# %%
df1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df1['Age'].value_counts()
# Out:
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 46    13
# 43    13
# 40    13
# 39    12
# 35    10
# 50     8
# 51     8
# 52     8
# 44     8
# 58     7
# 47     6
# 54     6
# 49     5
# 48     5
# 57     5
# 53     5
# 60     5
# 66     4
# 63     4
# 62     4
# 55     4
# 67     3
# 56     3
# 59     3
# 65     3
# 69     2
# 61     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: Age, dtype: int64

# %%
df1.aggregate({'Pregnancies':'mean','Glucose':'sum', 'BloodPressure':'min'})
# Out:
# Pregnancies          3.845052
# Glucose          92847.000000
# BloodPressure        0.000000
# dtype: float64

# %%
df.melt()
# Out:
#       variable           value
# 0           ID         1312200
# 1           ID         1312199
# 2           ID         1312198
# 3           ID         1312197
# 4           ID         1304116
# ...        ...             ...
# 18995  Umpire2     K Hariharan
# 18996  Umpire2       DJ Harper
# 18997  Umpire2  GA Pratapkumar
# 18998  Umpire2      SL Shastri
# 18999  Umpire2     RE Koertzen
#
# [19000 rows x 2 columns]
