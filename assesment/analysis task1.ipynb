# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 5. You have been given a dataset named sales_data.csv that contains information about sales transactions. The dataset has columns date, product_id, quantity, and revenue. Write a Python script to read the dataset, manipulate the data to calculate the total revenue for each product, and then create a bar plot to visualize the top 10 products by revenue.

# %%
df=pd.read_csv(r"C:\Users\pbann\Downloads\sales_data.csv")

# %%
df
# Out:
#          date  product_id  quantity  revenue
# 0  01-07-2023        1001        10      100
# 1  01-07-2023        1002         5       75
# 2  02-07-2023        1001         8       80
# 3  02-07-2023        1003         3       45
# 4  03-07-2023        1002        12      180
# 5  03-07-2023        1003         6       90
# 6  04-07-2023        1001        15      150
# 7  04-07-2023        1002         7      105
# 8  04-07-2023        1003         9      135

# %%
sum1=df.groupby('product_id')['revenue'].sum()

# %%
plt.bar(sum1.index,sum1.values)
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# 3. 1. Account: This table contains information about the accounts held by the bank's clients. It includes the account ID, the date the account was opened, the associated client ID, and the account type.
# 2. Card: This table contains information about the card issued by the bank. It includes the card ID, the date the card was issued, and the card type.
# 3. Client: This table contains information about the bank's clients. It includes the client ID, the client's birthdate, gender, and the district where the client lives.
# 4. Disposition: This table contains information about the relationship between clients and their accounts. It includes the disposition ID, the client ID associated with the disposition, and the type of disposition (e.g., owner, authorized person, etc.).
# 5. District: This table contains information about the various districts in Czechoslovakia. It includes the district ID, the name of the district, and various demographic and economic indicators for the district.
# 6. Loan: This table contains information about the loans issued by the bank. It includes the loan ID, the date the loan was issued, the account ID associated with the loan, the amount of the loan.
# 7. Order: This table contains information about the orders issued by the bank's clients. It includes the order ID, the account ID associated with the order, the date the order was issued, and a description of the order.
# 8. Transaction: This table contains information about the transactions made by the bank's clients. It includes the transaction ID, the account ID associated

# %%
account_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\account.csv",delimiter=';')
account_df
# Out:
#       account_id  district_id         frequency    date
# 0            576           55  POPLATEK MESICNE  930101
# 1           3818           74  POPLATEK MESICNE  930101
# 2            704           55  POPLATEK MESICNE  930101
# 3           2378           16  POPLATEK MESICNE  930101
# 4           2632           24  POPLATEK MESICNE  930102
# ...          ...          ...               ...     ...
# 4495         124           55  POPLATEK MESICNE  971228
# 4496        3958           59  POPLATEK MESICNE  971228
# 4497         777           30  POPLATEK MESICNE  971228
# 4498        1573           63  POPLATEK MESICNE  971229
# 4499        3276            1  POPLATEK MESICNE  971229
#
# [4500 rows x 4 columns]

# %%
card_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\card.csv",delimiter=';')
card_df
# Out:
#      card_id  disp_id     type           issued
# 0       1005     9285  classic  931107 00:00:00
# 1        104      588  classic  940119 00:00:00
# 2        747     4915  classic  940205 00:00:00
# 3         70      439  classic  940208 00:00:00
# 4        577     3687  classic  940215 00:00:00
# ..       ...      ...      ...              ...
# 887      125      694     gold  981226 00:00:00
# 888      674     4360  classic  981228 00:00:00
# 889      322     2063  classic  981228 00:00:00
# 890      685     4467  classic  981229 00:00:00
# 891      635     4083  classic  981229 00:00:00
#
# [892 rows x 4 columns]

# %%
client_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\client.csv",delimiter=';')
client_df
# Out:
#       client_id  birth_number  district_id
# 0             1        706213           18
# 1             2        450204            1
# 2             3        406009            1
# 3             4        561201            5
# 4             5        605703            5
# ...         ...           ...          ...
# 5364      13955        456030            1
# 5365      13956        430406            1
# 5366      13968        680413           61
# 5367      13971        626019           67
# 5368      13998        535812           74
#
# [5369 rows x 3 columns]

# %%
disposition_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\disp.csv",delimiter=';')
disposition_df
# Out:
#       disp_id  client_id  account_id       type
# 0           1          1           1      OWNER
# 1           2          2           2      OWNER
# 2           3          3           2  DISPONENT
# 3           4          4           3      OWNER
# 4           5          5           3  DISPONENT
# ...       ...        ...         ...        ...
# 5364    13647      13955       11349      OWNER
# 5365    13648      13956       11349  DISPONENT
# 5366    13660      13968       11359      OWNER
# 5367    13663      13971       11362      OWNER
# 5368    13690      13998       11382      OWNER
#
# [5369 rows x 4 columns]

# %%
district_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\district.csv",delimiter=';')
district_df
# Out:
#     A1               A2               A3       A4  A5  A6  A7  A8  A9    A10  \
# 0    1      Hl.m. Praha           Prague  1204953   0   0   0   1   1  100.0
# 1    2          Benesov  central Bohemia    88884  80  26   6   2   5   46.7
# 2    3           Beroun  central Bohemia    75232  55  26   4   1   5   41.7
# 3    4           Kladno  central Bohemia   149893  63  29   6   2   6   67.4
# 4    5            Kolin  central Bohemia    95616  65  30   4   1   6   51.4
# ..  ..              ...              ...      ...  ..  ..  ..  ..  ..    ...
# 72  73            Opava    north Moravia   182027  17  49  12   2   7   56.4
# 73  74  Ostrava - mesto    north Moravia   323870   0   0   0   1   1  100.0
# 74  75           Prerov    north Moravia   138032  67  30   4   2   5   64.6
# 75  76          Sumperk    north Moravia   127369  31  32  13   2   7   51.2
# 76  77           Vsetin    north Moravia   148545   8  35  12   3   4   53.5
#
#       A11   A12   A13  A14    A15    A16
# ...

# %%
loan_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\loan.csv",delimiter=';')
loan_df
# Out:
#      loan_id  account_id    date  amount  duration  payments status
# 0       5314        1787  930705   96396        12    8033.0      B
# 1       5316        1801  930711  165960        36    4610.0      A
# 2       6863        9188  930728  127080        60    2118.0      A
# 3       5325        1843  930803  105804        36    2939.0      A
# 4       7240       11013  930906  274740        60    4579.0      A
# ..       ...         ...     ...     ...       ...       ...    ...
# 677     4989         105  981205  352704        48    7348.0      C
# 678     5221        1284  981205   52512        12    4376.0      C
# 679     6402        6922  981206  139488        24    5812.0      C
# 680     5346        1928  981206   55632        24    2318.0      C
# 681     6748        8645  981208  240900        60    4015.0      C
#
# [682 rows x 7 columns]

# %%
order_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\order.csv",delimiter=';')
order_df
# Out:
#       order_id  account_id bank_to  account_to  amount  k_symbol
# 0        29401           1      YZ    87144583  2452.0      SIPO
# 1        29402           2      ST    89597016  3372.7      UVER
# 2        29403           2      QR    13943797  7266.0      SIPO
# 3        29404           3      WX    83084338  1135.0      SIPO
# 4        29405           3      CD    24485939   327.0
# ...        ...         ...     ...         ...     ...       ...
# 6466     46334       11362      YZ    70641225  4780.0      SIPO
# 6467     46335       11362      MN    78507822    56.0
# 6468     46336       11362      ST    40799850   330.0  POJISTNE
# 6469     46337       11362      KL    20009470   129.0
# 6470     46338       11362      MN    61540514  5392.0      UVER
#
# [6471 rows x 6 columns]

# %%
trans_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\trans.csv",delimiter=';')
trans_df
# Out:
# C:\Users\pbann\AppData\Local\Temp\ipykernel_23036\1338041265.py:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   trans_df=pd.read_csv(r"C:\Users\pbann\Downloads\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\lpetrocelli-czech-financial-dataset-real-anonymized-transactions\trans.csv",delimiter=';')
#          trans_id  account_id    date    type operation  amount  balance  \
# 0          695247        2378  930101  PRIJEM     VKLAD   700.0    700.0
# 1          171812         576  930101  PRIJEM     VKLAD   900.0    900.0
# 2          207264         704  930101  PRIJEM     VKLAD  1000.0   1000.0
# 3         1117247        3818  930101  PRIJEM     VKLAD   600.0    600.0
# 4          579373        1972  930102  PRIJEM     VKLAD   400.0    400.0
# ...           ...         ...     ...     ...       ...     ...      ...
# 1056315   3626622        2906  981231  PRIJEM       NaN    62.3  13729.4
# ...

# %% [markdown]
# 1. What is the demographic profile of the bank's clients and how does it vary across districts?
# 2. How the banks have performed over the years. Give their detailed analysis year & month-wise.
# 3. What are the most common types of accounts and how do they differ in terms of usage and profitability?
# 4. Which types of cards are most frequently used by the bank's clients and what is the overall profitability of the credit card business?
# 5. What are the major expenses of the bank and how can they be reduced to improve profitability?
# 6. What is the bank’s loan portfolio and how does it vary across different purposes and client segments?
# 7. How can the bank improve its customer service and satisfaction levels?
# 8. Can the bank introduce new financial products or services to attract more customers and increase profitability?
# The objective of this analysis is to provide the Czechoslovakia Bank with actionable insights that can help them make informed decisions about their financial operations. The analysis will involve data cleaning, exploratory data analysis, and predictive modelling to identify patterns and trends in the data.

# %%
district_df.rename(columns={'A1':'district_id',
                           'A2':'dist_name','A3':'Region','A4':'no_of_inhibitants','A5':'municipalities_with_inhibitants_less_tha_499','A6':'m_between_500_1999','A7':'m_between_2000_9999','A8':'m_lessthan_10000','A9':'no_of_cities','A10':'ratio_of_urban_inhabits','A11':'avg_salary','A12':'enp_1000_inhabitants'},inplace=True)

# %%
demograph_df=pd.merge(account_df,district_df,on='district_id')

# %%
demograph_df.head(3)
# Out:
#    account_id  district_id         frequency    date      dist_name  \
# 0         576           55  POPLATEK MESICNE  930101  Brno - venkov
# 1         704           55  POPLATEK MESICNE  930101  Brno - venkov
# 2         192           55  POPLATEK MESICNE  930108  Brno - venkov
#
#           Region  no_of_inhibitants  \
# 0  south Moravia             157042
# 1  south Moravia             157042
# 2  south Moravia             157042
#
#    municipalities_with_inhibitants_less_tha_499  m_between_500_1999  \
# 0                                            49                  70
# 1                                            49                  70
# 2                                            49                  70
#
#    m_between_2000_9999  m_lessthan_10000  no_of_cities  \
# 0                   18                 0             9
# 1                   18                 0             9
# 2                   18                 0             9
#
# ...

# %%
df=demograph_df.copy()

# %%
counts=df.groupby('district_id')['account_id'].count()

# %%
plt.bar(counts.index, counts.values)

# Add labels and title
plt.xlabel('District ID')
plt.ylabel('Number of Accounts')
plt.title('Number of Accounts per District')
# Show the plot
plt.show()

# %% [markdown]
# # observations:

# %% [markdown]
# 1. What is the demographic profile of the bank's clients and how does it vary across districts?
# #### ans. 90 % of districts having same proportions of accounts

# %% [markdown]
# 2. How the banks have performed over the years. Give their detailed analysis year & month-wise.

# %%
performance_df=pd.merge(account_df,loan_df,on='account_id')
performance_df
# Out:
#      account_id  district_id         frequency  date_x  loan_id  date_y  \
# 0          5270           44  POPLATEK MESICNE  930113     6077  931122
# 1         11265           15  POPLATEK MESICNE  930114     7284  930915
# 2         10364           55  POPLATEK MESICNE  930117     7121  931110
# 3          3834           54  POPLATEK MESICNE  930119     5754  940928
# 4          9307           68  POPLATEK MESICNE  930124     6895  940919
# ..          ...          ...               ...     ...      ...     ...
# 677        9227           51  POPLATEK MESICNE  971104     6872  980429
# 678       10005           64  POPLATEK MESICNE  971129     7035  980729
# 679         276           38  POPLATEK MESICNE  971208     5027  981202
# 680         938           70  POPLATEK MESICNE  971213     5147  980521
# 681        1318           56  POPLATEK MESICNE  971222     5226  981011
#
#      amount  duration  payments status
# 0     79608        24    3317.0      A
# ...

# %%
status_counts = performance_df['status'].value_counts()

# Create a bar plot
plt.bar(status_counts.index, status_counts.values)

# Add labels and title
plt.xlabel('Status')
plt.ylabel('Count')
plt.title('Counts of each Status')

# Show the plot
plt.show()

# %% [markdown]
# ## observations:
# #### ----> as the data provided has loans as a key business performance finder as counts of D and B are very less this shows that business is running good so far on yearly basis
